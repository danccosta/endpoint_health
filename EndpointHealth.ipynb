# %% [markdown]
# ####Creating DataFrames and typecasting columns according to the documentation
# >admissions: https://mimic.mit.edu/docs/iv/modules/core/admissions/
# >d_labitens: https://mimic.mit.edu/docs/iv/modules/hosp/d_labitems/
# >edstays: https://mimic.mit.edu/docs/iv/modules/ed/edstays/
# >labevents: https://mimic.mit.edu/docs/iv/modules/hosp/labevents/

# %%
admissions_schema = """
subject_id INTEGER, 
hadm_id INTEGER, 
admittime TIMESTAMP, 
dischtime TIMESTAMP, 
deathtime TIMESTAMP, 
admission_type STRING, 
admission_location STRING, 
discharge_location STRING,
insurance STRING,
language STRING,
marital_status STRING,
ethnicity STRING,
edregtime TIMESTAMP,
edouttime TIMESTAMP,
hospital_expire_flag INTEGER"""

d_labitems_schema = """
itemid INTEGER,
label STRING,
fluid STRING,
category STRING,
loinc_code STRING"""

edstays_schema = """
subject_id INTEGER, 
hadm_id INTEGER, 
stay_id INTEGER, 
intime TIMESTAMP, 
outtime TIMESTAMP"""

labevents_schema = """
labevent_id	INTEGER,
subject_id INTEGER,
hadm_id INTEGER,
specimen_id	INTEGER,
itemid INTEGER,
charttime TIMESTAMP,
storetime TIMESTAMP,
value STRING,
valuenum DOUBLE,
valueuom STRING,
ref_range_lower DOUBLE,
ref_range_upper	DOUBLE,
flag STRING,
priority STRING,
comments STRING
"""

admissionsDf = spark.read.options(header=True).schema(admissions_schema).csv("dbfs:/FileStore/tables/admissions.csv")
d_labitemsDf = spark.read.options(header=True).schema(d_labitems_schema).csv("dbfs:/FileStore/tables/d_labitems.csv")
edstaysDf = spark.read.options(header=True).schema(edstays_schema).csv("dbfs:/FileStore/tables/edstays.csv")
labeventsDf = spark.read.options(header=True).schema(labevents_schema).csv("dbfs:/FileStore/tables/labevents.csv")

# %%
admissionsDf.printSchema()
# Out:
# root
#  |-- subject_id: integer (nullable = true)
#  |-- hadm_id: integer (nullable = true)
#  |-- admittime: timestamp (nullable = true)
#  |-- dischtime: timestamp (nullable = true)
#  |-- deathtime: timestamp (nullable = true)
#  |-- admission_type: string (nullable = true)
#  |-- admission_location: string (nullable = true)
#  |-- discharge_location: string (nullable = true)
#  |-- insurance: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- ethnicity: string (nullable = true)
#  |-- edregtime: timestamp (nullable = true)
#  |-- edouttime: timestamp (nullable = true)
#  |-- hospital_expire_flag: integer (nullable = true)

# %%
d_labitemsDf.printSchema()
# Out:
# root
#  |-- itemid: integer (nullable = true)
#  |-- label: string (nullable = true)
#  |-- fluid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- loinc_code: string (nullable = true)

# %%
edstaysDf.printSchema()
# Out:
# root
#  |-- subject_id: integer (nullable = true)
#  |-- hadm_id: integer (nullable = true)
#  |-- stay_id: integer (nullable = true)
#  |-- intime: timestamp (nullable = true)
#  |-- outtime: timestamp (nullable = true)

# %%
labeventsDf.printSchema()
# Out:
# root
#  |-- labevent_id: integer (nullable = true)
#  |-- subject_id: integer (nullable = true)
#  |-- hadm_id: integer (nullable = true)
#  |-- specimen_id: integer (nullable = true)
#  |-- itemid: integer (nullable = true)
#  |-- charttime: timestamp (nullable = true)
#  |-- storetime: timestamp (nullable = true)
#  |-- value: string (nullable = true)
#  |-- valuenum: double (nullable = true)
#  |-- valueuom: string (nullable = true)
#  |-- ref_range_lower: double (nullable = true)
#  |-- ref_range_upper: double (nullable = true)
#  |-- flag: string (nullable = true)
#  |-- priority: string (nullable = true)
#  |-- comments: string (nullable = true)

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

# %% [markdown]
# ####What is the percentage of patients admitted to the hospital that have never been to the ED?
# >The edstays table gives us the information about patients admited to ED (https://mimic.mit.edu/docs/iv/modules/ed/edstays/)
# >

# %%
patientsEDDf = admissionsDf.join(edstaysDf,["subject_id","hadm_id"],"left") \
.groupBy("subject_id").agg(sum("stay_id").alias("sum_stay_id"))

patientsEDDf.createOrReplaceTempView("patientsED")

display(
    spark.sql("""
        SELECT
            COUNT(DISTINCT(subject_id)) AS count_total_patients,
            ((COUNT(DISTINCT(subject_id)) FILTER(WHERE sum_stay_id IS NOT NULL))/COUNT(DISTINCT(subject_id)))*100 AS percentage_patients_ed,
            ((COUNT(DISTINCT(subject_id)) FILTER(WHERE sum_stay_id IS NULL))/COUNT(DISTINCT(subject_id)))*100 AS percentage_patients_not_ed            
        FROM patientsED
    """)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count_total_patients</th><th>percentage_patients_ed</th><th>percentage_patients_not_ed</th></tr></thead><tbody><tr><td>100</td><td>62.0</td><td>38.0</td></tr></tbody></table></div>

# %% [markdown]
# ####For each patient, generate a json with the hospital admission data.
# >Admission data is in table admissions (https://mimic.mit.edu/docs/iv/modules/core/admissions/)

# %%
subject_list = admissionsDf.select("subject_id").distinct().collect() # Getting distinct subject_id as python list of Rows
output_basepath = "dbfs:/FileStore/tables/subject"
for row in subject_list:
    subject = row.subject_id
    df = admissionsDf.filter(f"subject_id = {subject}") # Creating a DataFrame for each subject_id
    df.write.mode("overwrite").json(f"{output_basepath}/subject_{subject}") # Writing as Json in output basepath with naming convention: subject_[subject_id]
dbutils.fs.ls("dbfs:/FileStore/tables/subject")
# Out:
# Out[69]: [FileInfo(path='dbfs:/FileStore/tables/subject/subject_10000032/', name='subject_10000032/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10001217/', name='subject_10001217/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10001725/', name='subject_10001725/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10002428/', name='subject_10002428/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10002495/', name='subject_10002495/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10002930/', name='subject_10002930/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10003046/', name='subject_10003046/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10003400/', name='subject_10003400/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10004235/', name='subject_10004235/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10004422/', name='subject_10004422/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10004457/', name='subject_10004457/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10004720/', name='subject_10004720/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10004733/', name='subject_10004733/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10005348/', name='subject_10005348/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10005817/', name='subject_10005817/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10005866/', name='subject_10005866/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10005909/', name='subject_10005909/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10006053/', name='subject_10006053/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10006580/', name='subject_10006580/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10007058/', name='subject_10007058/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10007795/', name='subject_10007795/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10007818/', name='subject_10007818/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10007928/', name='subject_10007928/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10008287/', name='subject_10008287/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10008454/', name='subject_10008454/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10009035/', name='subject_10009035/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10009049/', name='subject_10009049/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10009628/', name='subject_10009628/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10010471/', name='subject_10010471/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10010867/', name='subject_10010867/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10011398/', name='subject_10011398/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10012552/', name='subject_10012552/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10012853/', name='subject_10012853/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10013049/', name='subject_10013049/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10014078/', name='subject_10014078/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10014354/', name='subject_10014354/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10014729/', name='subject_10014729/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10015272/', name='subject_10015272/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10015860/', name='subject_10015860/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10015931/', name='subject_10015931/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10016150/', name='subject_10016150/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10016742/', name='subject_10016742/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10016810/', name='subject_10016810/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10017492/', name='subject_10017492/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10018081/', name='subject_10018081/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10018328/', name='subject_10018328/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10018423/', name='subject_10018423/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10018501/', name='subject_10018501/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10018845/', name='subject_10018845/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019003/', name='subject_10019003/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019172/', name='subject_10019172/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019385/', name='subject_10019385/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019568/', name='subject_10019568/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019777/', name='subject_10019777/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10019917/', name='subject_10019917/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020187/', name='subject_10020187/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020306/', name='subject_10020306/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020640/', name='subject_10020640/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020740/', name='subject_10020740/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020786/', name='subject_10020786/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10020944/', name='subject_10020944/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10021118/', name='subject_10021118/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10021312/', name='subject_10021312/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10021487/', name='subject_10021487/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10021666/', name='subject_10021666/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10021938/', name='subject_10021938/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10022017/', name='subject_10022017/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10022041/', name='subject_10022041/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10022281/', name='subject_10022281/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10022880/', name='subject_10022880/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10023117/', name='subject_10023117/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10023239/', name='subject_10023239/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10023771/', name='subject_10023771/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10024043/', name='subject_10024043/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10025463/', name='subject_10025463/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10025612/', name='subject_10025612/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10026255/', name='subject_10026255/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10026354/', name='subject_10026354/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10026406/', name='subject_10026406/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10027445/', name='subject_10027445/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10027602/', name='subject_10027602/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10029291/', name='subject_10029291/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10029484/', name='subject_10029484/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10031404/', name='subject_10031404/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10031757/', name='subject_10031757/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10032725/', name='subject_10032725/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10035185/', name='subject_10035185/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10035631/', name='subject_10035631/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10036156/', name='subject_10036156/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10037861/', name='subject_10037861/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10037928/', name='subject_10037928/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10037975/', name='subject_10037975/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10038081/', name='subject_10038081/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10038933/', name='subject_10038933/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10038992/', name='subject_10038992/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10038999/', name='subject_10038999/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10039708/', name='subject_10039708/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10039831/', name='subject_10039831/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10039997/', name='subject_10039997/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/FileStore/tables/subject/subject_10040025/', name='subject_10040025/', size=0, modificationTime=0)]

# %% [markdown]
# ####Check the performance of albumin in predicting in-hospital mortality.
# Use only each patient’s first admission to the hospital; and only the Albumin results from the first 24h from hospital admission.
# >Column deathtime from admissions indicates if patient died in the hospital, if Null the patient didn't die (https://mimic.mit.edu/docs/iv/modules/core/admissions/)
# >All 3 patients treated with Albumin within 24h from admission to the hospital survived

# %%
patientsAlbuminDf = admissionsDf.join(labeventsDf,["subject_id","hadm_id"],"left") \
.join(d_labitemsDf,["itemid"],"left") \
.where("lower(label) like '%albumin%'") \
.withColumn("row_number",row_number().over(Window.partitionBy("subject_id").orderBy("admittime"))).filter(col("row_number")==1) \
.withColumn("timedelta", (col("dischtime").cast("long") - col("admittime").cast("long"))/3600) \
.filter("timedelta <= 24.0") \
.drop("row_number")

display(patientsAlbuminDf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th